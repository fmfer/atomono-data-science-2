# %% [markdown]
# # 分析
#
# 本当は1日単位でDailyでとって変遷まで見たかったが、
# 間に合わないのでWeeklyで取るしかない。

# %% [markdown]
# ## fun_done_learn_10_24_10_30

# %% [markdown]
# ### 文字数

# %% [markdown]
# #### JIRAデータ
#
# 下処理について
# * JIRA(1).csvとJIRA.csvを合わせた。
# * commnetの項目が全部同じなのでcommentをcommnet1, commnet2, commnet3, commnet4 に変更
# * その後必要なデータのみを集めておく.

# %%
import pandas as pd #pandasをpdとしてインポート
 
#データをdfに読み込み。pandasをpdとして利用。
df = pd.read_csv("material/fun_done_learn_10_24_10_30/Jira.csv")

# 必要な列だけを含む新しいDataFrameを作成する
new_df = df[["Summary", "Reporter","Description", "Comment1", "Comment2"]].copy()

# 各列の文字数をカウントする
new_df['Description_length'] = new_df['Description'].str.len()
new_df['Comment1_length'] = new_df['Comment1'].str.len()
new_df['Comment2_length'] = new_df['Comment2'].str.len()

# レポーターごとに文字数を合計する
reporter_counts = new_df.groupby('Reporter').sum()

# 結果を表示する
print(reporter_counts)

# 結果をマークダウン形式に変換する
markdown = reporter_counts.to_markdown()

# 結果を表示する
# print(markdown)
# Out:
#                                                           Summary  \
# Reporter
# Dai Miyahara    ユーザーが廃盤品に関連する代替品を一つ見つけることができることユーザーが廃盤品の詳細情報を確...
# Fernández       FE: ユーザーはログインができる、FE/BEを繋ぎ込むFE: ユーザーはログインができる、...
# HibikiMizuno    ユーザーが廃盤品の代替品の詳細を調べることができることフロントエンド実装：商品概要フロントエ...
# Kenta Nakayama     【イベント】8/5 前期発表【イベント】メーカー側にインタビューマンスリーレビューの資料作成
# satoshi.hirata  BE: ユーザ本人以外リストを編集できないように認可処理を追加するBE: railsのバージ...
#
#                                                       Description  \
# Reporter
# Dai Miyahara    products/{id}のrelatives\n\nDB上は何ベースの代替品かは把握できて...
# Fernández                                                       0
# HibikiMizuno    !スクリーンショット 2023-07-09 1.35.31 (c3070130-1b01-4...
# Kenta Nakayama                                                  0
# satoshi.hirata                                                  0
#
#                                                          Comment1  \
# Reporter
# Dai Miyahara                                                    0
# Fernández       27/Oct/23 1:01 AM;712020:744719ff-9f36-45ea-ad...
# HibikiMizuno    25/Oct/23 4:19 AM;62d6d768657fc166e26036e9;[ht...
# Kenta Nakayama                                                  0
# satoshi.hirata  24/Oct/23 9:35 AM;63987e6af78d12c0f47112a9;[ht...
#
#                                                          Comment2  \
# Reporter
# Dai Miyahara                                                    0
# Fernández       27/Oct/23 10:40 PM;712020:744719ff-9f36-45ea-a...
# HibikiMizuno                                                    0
# Kenta Nakayama                                                  0
# satoshi.hirata                                                  0
#
#                 Description_length  Comment1_length  Comment2_length
# Reporter
# Dai Miyahara                 133.0              0.0              0.0
# Fernández                      0.0            283.0             99.0
# HibikiMizuno                3083.0            360.0              0.0
# Kenta Nakayama                 0.0              0.0              0.0
# satoshi.hirata                 0.0            362.0              0.0
# /var/folders/8n/7ctlqx_n0555kxyc9jz4f2x40000gn/T/ipykernel_6398/4057137294.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd #pandasをpdとしてインポート

# %% [markdown]
# #### Slack
#
# 下処理について
#
# * 不要なjsonデータは削除しました
#   * 主にトップフォルダの内容

# %%
import os
import json

# JSONファイルが格納されているディレクトリのパス
directory = 'material/fun_done_learn_10_24_10_30/slack/'

# 文字数の合計を格納する変数
total_characters = 0

# ディレクトリとそのサブディレクトリ内のすべてのファイルを読み込む
for subdir, dirs, files in os.walk(directory):
    for filename in files:
        if filename.endswith(".json"): 
            filepath = subdir + os.sep + filename
            with open(filepath, 'r') as f:
                data = json.load(f)
                for message in data:
                    if 'text' in message:
                        text = message['text']
                        total_characters += len(text)

print(f"Total number of characters: {total_characters}")
# Out:
# Total number of characters: 50238

# %%
import pandas as pd

df = pd.read_csv("material/fun_done_learn_10_24_10_30/Slack_channel.csv")
df
# Out:
#                        Name  \
# 0           atomono-backend
# 1               atomono-dev
# 2          atomono-frontend
# 3              atomono-jira
# 4                 chit-chat
# 5      daily-satoshi-hirata
# 6           data-collection
# 7                   general
# 8            github-backend
# 9                     lives
# 10                 meetings
# 11         share-attendance
# 12   share-scrum-activities
# 13      share-starting-work
# 14              study-agile
# 15            study-backend
# 16           study-frontend
# 17       times-dai-miyahara
# 18          times-fernandez
# 19      times-hibiki-mizuno
# 20        times-hiroto-ohno
# 21        times-maki-suzuki
# 22           times-nakayama
# 23     times-satoshi-hirata
# 24                     tips
# 25                    ui-ux
# 26      web-services-status
# 27  z_archived_test_general
#
#                                           Description Visibility  \
# 0                                  バックエンドのメインチャンネルです。     public
# 1                                                 NaN     public
# 2   フロントエンドのメインチャンネルです。\n\nprod環境: <https://atomon...     public
# 3                   JIRA上で管理しているタスクのイベントが通知されるチャンネルです     public
# 4                                         雑談のチャンネルです。     public
# 5                                         ひらたの日報チャンネル     public
# 6                                                 NaN     public
# 7   このチャンネルでは、どんなことでも話せます。チーム内のジョークや、とっさに思い付いたアイデア...     public
# 8                                                 NaN     public
# 9                                                 NaN     public
# 10                                                NaN     public
# 11                               お休みや参加できない場合は報告しましょう     public
# 12              Describe scrum activity in bot thread     public
# 13           作業開始や終了など作業してるかわかりやすくなるため。同期できる時にしやすくする。     public
# 14                                                NaN     public
# 15                                                NaN     public
# 16                                                NaN     public
# 17                             宮原大のtimes, 色々なことつぶやきます     public
# 18                                                NaN     public
# 19                                            分報チャンネル     public
# 20                                                NaN     public
# 21                                                NaN     public
# 22                                                NaN     public
# 23  分報ch。作業中に調べためもや進捗や雑談めいた独り言もぼやきます。入退出ご自由にどうぞ:me...     public
# 24                                                NaN     public
# 25            UserInterfaceとUserExperienceについて話すチャンネル     public
# 26                                                NaN     public
# 27   このチャンネルには、常にすべてのメンバーが含まれます。社内通知やチーム全体の会話にぴったりです。     public
#
#          Created  Total membership  Messages posted  Members who posted  \
# 0   Apr 26, 2023                 8                8                   3
# 1    May 6, 2023                 8               48                   5
# 2   Apr 25, 2023                 8              108                   7
# 3   Apr 26, 2023                 8                5                   2
# 4   May 13, 2023                 5                7                   3
# 5   Jul 12, 2023                 1                7                   1
# 6    Sep 5, 2023                 8                0                   0
# 7   Mar 11, 2023                 8                2                   1
# 8   May 30, 2023                 1                0                   0
# 9    Aug 5, 2023                 8                0                   0
# 10  Apr 18, 2023                 8               64                   4
# 11  Apr 24, 2023                 8                4                   4
# 12   Apr 4, 2023                 8               22                   6
# 13  Oct 10, 2023                 8               43                   7
# 14  May 23, 2023                 8                0                   0
# 15  May 23, 2023                 8                0                   0
# 16  May 23, 2023                 4                9                   3
# 17  Apr 18, 2023                 8                4                   1
# 18  May 11, 2023                 8               13                   2
# 19  Apr 15, 2023                 7               69                   4
# 20  May 16, 2023                 8               28                   4
# 21  May 16, 2023                 8                0                   0
# 22  Apr 18, 2023                 8               12                   2
# 23  Apr 15, 2023                 7               27                   3
# 24  Apr 15, 2023                 8               11                   3
# 25  Apr 25, 2023                 8                0                   0
# 26   Aug 3, 2023                 1                4                   0
# 27  Mar 11, 2023                 8                0                   0
#
#     Members who viewed
# 0                    7
# 1                    7
# 2                    7
# 3                    6
# 4                    5
# 5                    1
# 6                    0
# 7                    7
# 8                    1
# 9                    0
# 10                   7
# 11                   7
# 12                   7
# 13                   7
# 14                   0
# 15                   0
# 16                   4
# 17                   7
# 18                   7
# 19                   7
# 20                   7
# 21                   2
# 22                   7
# 23                   7
# 24                   7
# 25                   0
# 26                   1
# 27                   0

# %%
df = pd.read_csv("material/fun_done_learn_10_24_10_30/Slack_member.csv")
df
# Out:
#                   Name  What I Do Account type Account created (UTC)  \
# 0         Dai Miyahara        NaN       Member          Mar 11, 2023
# 1  FABIAN M. FERNANDEZ        NaN       Member          Mar 11, 2023
# 2        Hibiki Mizuno        NaN       Member          Mar 11, 2023
# 3       Nakayama Kenta        NaN        Owner          Mar 11, 2023
# 4          Ohno Hiroto        NaN       Member          Mar 11, 2023
# 5      satoshi.​hirata        NaN        Owner          Mar 11, 2023
# 6                   yc        NaN        Owner          Mar 11, 2023
# 7                 鈴木真希        NaN       Member          Mar 11, 2023
#
#    Days active  Messages posted
# 0            7               75
# 1            6               50
# 2            7              137
# 3            7               99
# 4            7               59
# 5            7               62
# 6            0                0
# 7            7               15

# %% [markdown]
# #### Notion

# %%
# マークダウンファイルのパス
filepath = 'material/fun_done_learn_10_24_10_30/Notion.md'

# ファイルを開き、内容を読み込む
with open(filepath, 'r') as f:
    content = f.read()

# 文字数を数える
num_characters = len(content)

print(f"Number of characters: {num_characters}")
# Out:
# Number of characters: 4624

# %% [markdown]
# #### Figjam

# %%
import pandas as pd

# CSVファイルのパス
filepath = 'material/fun_done_learn_10_24_10_30/figjam.csv'

# CSVファイルを読み込む
df = pd.read_csv(filepath)

# 'Content'列の文字数をカウントする
df['char_count'] = df['Content'].str.len()

# 'Created by'でグループ化し、各グループの文字数の合計を計算する
char_count_by_creator = df.groupby('Created by')['char_count'].sum()

print(char_count_by_creator)
# Out:
# Created by
# Dai Miyahara            95
# FABIAN M. FERNANDEZ    139
# 中山建太                   323
# 大野寛人                    68
# 平田聖                    295
# 水野響                    230
# 鈴木真希                    97
# Name: char_count, dtype: int64

# %% [markdown]
# ### 文章量

# %% [markdown]
# #### JIRA

# %%
import pandas as pd
import MeCab
import ipadic

CHASEN_ARGS = r' -F "%m\t%f[7]\t%f[6]\t%F-[0,1,2,3]\t%f[4]\t%f[5]\n"'
CHASEN_ARGS += r' -U "%m\t%m\t%m\t%F-[0,1,2,3]\t\t\n"'

# データをdfに読み込み
df = pd.read_csv("material/fun_done_learn_10_24_10_30/Jira.csv")

# 必要な列だけを含む新しいDataFrameを作成する
new_df = df[["Summary", "Reporter","Description", "Comment1", "Comment2"]].copy()

# MeCabのインスタンスを作成
#m = MeCab.Tagger("-Owakati")
m = MeCab.Tagger(ipadic.MECAB_ARGS + CHASEN_ARGS)


# 文章数と単語数をカウントする関数を定義
def count_sentences_and_words(text):
    if not isinstance(text, str):
        return pd.Series([0, 0])
    sentences = text.count('。') + text.count('！') + text.count('？') + text.count('\n') + text.count(',') + 1

    words = len(m.parse(text).splitlines()[:-1])
    return pd.Series([sentences, words])

# 各列に関数を適用して新しい列を作成
for col in ["Description", "Comment1", "Comment2"]:
    new_df[[f'{col}_sentences', f'{col}_words']] = new_df[col].apply(count_sentences_and_words)

# レポーターごとに文章数と単語数を合計
reporter_counts = new_df.groupby('Reporter').sum()

# 各レポーターの単語数と文章数の合計を計算
reporter_counts['total_sentences'] = reporter_counts[[f'{col}_sentences' for col in ["Description", "Comment1", "Comment2"]]].sum(axis=1)
reporter_counts['total_words'] = reporter_counts[[f'{col}_words' for col in ["Description", "Comment1", "Comment2"]]].sum(axis=1)

# 結果を表示
print(reporter_counts[['total_sentences', 'total_words']])
# Out:
#                 total_sentences  total_words
# Reporter
# Dai Miyahara                  9           68
# Fernández                     6          174
# HibikiMizuno                 81         1448
# Kenta Nakayama                0            0
# satoshi.hirata                5          146

# %% [markdown]
# #### Slack

# %%
import os
import json
import MeCab
import ipadic

CHASEN_ARGS = r' -F "%m\t%f[7]\t%f[6]\t%F-[0,1,2,3]\t%f[4]\t%f[5]\n"'
CHASEN_ARGS += r' -U "%m\t%m\t%m\t%F-[0,1,2,3]\t\t\n"'

# JSONファイルが格納されているディレクトリのパス
directory = 'material/fun_done_learn_10_24_10_30/'

# MeCabのインスタンスを作成
m = MeCab.Tagger(ipadic.MECAB_ARGS + CHASEN_ARGS)

# 文章数と単語数の合計を格納する変数
total_sentences = 0
total_words = 0

# ディレクトリとそのサブディレクトリ内のすべてのファイルを読み込む
for subdir, dirs, files in os.walk(directory):
    for filename in files:
        if filename.endswith(".json"): 
            filepath = subdir + os.sep + filename
            with open(filepath, 'r') as f:
                data = json.load(f)
                for message in data:
                    if 'text' in message:
                        text = message['text']
                        total_sentences += text.count('.') + text.count('!') + text.count('?') + text.count('\n') + text.count(',')
                        total_words += len(m.parse(text).split())

print(f"Total number of sentences: {total_sentences}")
print(f"Total number of words: {total_words}")
# Out:
# Total number of sentences: 1378
# Total number of words: 87212

# %% [markdown]
# #### Notion

# %%
import MeCab
import ipadic

CHASEN_ARGS = r' -F "%m\t%f[7]\t%f[6]\t%F-[0,1,2,3]\t%f[4]\t%f[5]\n"'
CHASEN_ARGS += r' -U "%m\t%m\t%m\t%F-[0,1,2,3]\t\t\n"'

# マークダウンファイルのパス
filepath = 'material/fun_done_learn_10_24_10_30/Notion.md'

# MeCabのインスタンスを作成
m = MeCab.Tagger(ipadic.MECAB_ARGS + CHASEN_ARGS)


# ファイルを開き、内容を読み込む
with open(filepath, 'r') as f:
    content = f.read()

# 文章数を数える
num_sentences = content.count('。') + content.count('！') + content.count('？') + content.count('\n') + content.count(',') + 1

# 単語数を数える
num_words = len(m.parse(content).split())

print(f"Number of sentences: {num_sentences}")
print(f"Number of words: {num_words}")
# Out:
# Number of sentences: 215
# Number of words: 7196

# %% [markdown]
# #### Figjam

# %%
import pandas as pd
import MeCab

# CSVファイルのパス
filepath = 'material/fun_done_learn_10_24_10_30/figjam.csv'

# CSVファイルを読み込む
df = pd.read_csv(filepath)

# MeCabの初期化
m = MeCab.Tagger("-Owakati")

# 'Content'列の各行を単語に分割し、単語の数をカウントする
df['word_count'] = df['Content'].apply(lambda x: len(m.parse(x).split()))

# 単語の合計数を計算する
total_word_count = df['word_count'].sum()

# 'Content'列の行数（文章の数）をカウントする
total_sentence_count = df['Content'].count()

print(f"Total number of words: {total_word_count}")
print(f"Total number of sentences: {total_sentence_count}")
# Out:
# Total number of words: 623
# Total number of sentences: 39

# %% [markdown]
# ### 単語のカウント数

# %% [markdown]
# #### JIRA

# %%
import pandas as pd
import MeCab
import ipadic
from collections import Counter

CHASEN_ARGS = r' -F "%m\t%f[7]\t%f[6]\t%F-[0,1,2,3]\t%f[4]\t%f[5]\n"'
CHASEN_ARGS += r' -U "%m\t%m\t%m\t%F-[0,1,2,3]\t\t\n"'

# データをdfに読み込み
df = pd.read_csv("material/fun_done_learn_10_24_10_30/Jira.csv")

# 必要な列だけを含む新しいDataFrameを作成する
new_df = df[["Summary", "Reporter","Description", "Comment1", "Comment2"]].copy()

# MeCabのインスタンスを作成
m = MeCab.Tagger(ipadic.MECAB_ARGS + CHASEN_ARGS)

# 単語をカウントする関数を定義
def count_words(text):
    if not isinstance(text, str):
        return []
    return m.parse(text).splitlines()[:-1]

# 各列に関数を適用して新しい列を作成
for col in ["Description", "Comment1", "Comment2"]:
    new_df[f'{col}_words'] = new_df[col].apply(count_words)

# レポーターごとに単語を集計
reporter_words = new_df.groupby('Reporter').sum()
        
# 各レポーターの最も頻繁に出現する単語の上位3つを計算
for reporter, row in reporter_words.iterrows():
    words = [word for sublist in row if isinstance(sublist, list) for word in sublist if not (word.split('\t')[3].startswith('記号') or word.split('\t')[3].startswith('助詞') or word.split('\t')[3].startswith('助動詞'))]  # 記号、助詞、助動詞を除外
    word_counts = Counter(words)
    top_three = word_counts.most_common(3)
    print(f'Reporter: {reporter}')
    for word, count in top_three:
        print(f'    Word: {word}, Count: {count}')
# Out:
# Reporter: Dai Miyahara
#     Word: relatives	relatives	relatives	名詞-一般		, Count: 2
#     Word: 代替	ダイタイ	代替	名詞-サ変接続		, Count: 2
#     Word: 品	ヒン	品	名詞-接尾-一般		, Count: 2
# Reporter: Fernández
#     Word: e	e	e	名詞-一般		, Count: 8
#     Word: b	b	b	名詞-一般		, Count: 8
#     Word: 4	4	4	名詞-数		, Count: 4
# Reporter: HibikiMizuno
#     Word: 3	3	3	名詞-数		, Count: 41
#     Word: E	E	E	名詞-一般		, Count: 40
#     Word: 2	2	2	名詞-数		, Count: 36
# Reporter: Kenta Nakayama
# Reporter: satoshi.hirata
#     Word: rspec	rspec	rspec	名詞-一般		, Count: 5
#     Word: https	https	https	名詞-一般		, Count: 4
#     Word: 9	9	9	名詞-数		, Count: 3

# %% [markdown]
# #### Slack

# %%
import os
import json
import MeCab
import ipadic
from collections import Counter
import re

CHASEN_ARGS = r' -F "%m\t%f[7]\t%f[6]\t%F-[0,1,2,3]\t%f[4]\t%f[5]\n"'
CHASEN_ARGS += r' -U "%m\t%m\t%m\t%F-[0,1,2,3]\t\t\n"'

# JSONファイルが格納されているディレクトリのパス
directory = 'material/fun_done_learn_10_24_10_30/'

# MeCabのインスタンスを作成
m = MeCab.Tagger(ipadic.MECAB_ARGS + CHASEN_ARGS)

# 単語のカウントを格納するCounterオブジェクト
word_counts = Counter()

# ディレクトリとそのサブディレクトリ内のすべてのファイルを読み込む
for subdir, dirs, files in os.walk(directory):
    for filename in files:
        if filename.endswith(".json"): 
            filepath = subdir + os.sep + filename
            with open(filepath, 'r') as f:
                data = json.load(f)
                for message in data:
                    if 'text' in message:
                        text = message['text']
                        # HTMLエンティティを除外
                        text = re.sub(r'&[a-z]+;', '', text)
                        parsed_text = m.parse(text).split('\n')
                        words = [word.split('\t')[0] for word in parsed_text if word.strip() and len(word.split('\t')) > 3 and (word.split('\t')[3].startswith('名詞') or word.split('\t')[3].startswith('動詞') or word.split('\t')[3].startswith('形容詞')) and len(word.split('\t')[0]) > 1 and not word.split('\t')[0].isalpha()]  # 名詞、動詞、形容詞のみを抽出し、一文字の単語や英字のみの単語を除外
                        word_counts.update(words)

# 最も頻繁に出現する単語の上位3つを出力
top_three = word_counts.most_common(3)
for word, count in top_three:
    print(f'Word: {word}, Count: {count}')
# Out:
# Word: 04, Count: 113
# Word: 10, Count: 69
# Word: 2023, Count: 58

# %% [markdown]
# #### Notion

# %%
import MeCab
import ipadic
from collections import Counter
import re

CHASEN_ARGS = r' -F "%m\t%f[7]\t%f[6]\t%F-[0,1,2,3]\t%f[4]\t%f[5]\n"'
CHASEN_ARGS += r' -U "%m\t%m\t%m\t%F-[0,1,2,3]\t\t\n"'

# マークダウンファイルのパス
filepath = 'material/fun_done_learn_10_24_10_30/Notion.md'

# MeCabのインスタンスを作成
m = MeCab.Tagger(ipadic.MECAB_ARGS + CHASEN_ARGS)

# 単語のカウントを格納するCounterオブジェクト
word_counts = Counter()

# ファイルを開き、内容を読み込む
with open(filepath, 'r') as f:
    content = f.read()

# テキストを解析し、単語を抽出
parsed_text = m.parse(content).split('\n')
words = [word.split('\t')[0] for word in parsed_text if word.strip() and len(word.split('\t')) > 3 and len(word.split('\t')[0]) > 1 and word.split('\t')[0].isalpha() and re.match(r'^[ぁ-ん]+$', word.split('\t')[0]) and not word.split('\t')[3].startswith('助詞')]  # ひらがなのみの単語を抽出し、助詞を除外

# 単語のカウントを更新
word_counts.update(words)

# 最も頻繁に出現する単語の上位3つを出力
top_three = word_counts.most_common(20)
for word, count in top_three:
    print(f'Word: {word}, Count: {count}')
# Out:
# Word: する, Count: 12
# Word: こと, Count: 11
# Word: いる, Count: 10
# Word: ない, Count: 8
# Word: ある, Count: 6
# Word: でき, Count: 5
# Word: ます, Count: 5
# Word: できる, Count: 5
# Word: なる, Count: 4
# Word: まし, Count: 4
# Word: いい, Count: 4
# Word: さん, Count: 4
# Word: もの, Count: 3
# Word: やすい, Count: 3
# Word: づらい, Count: 3
# Word: おなじく, Count: 3
# Word: どこ, Count: 2
# Word: なっ, Count: 2
# Word: ところ, Count: 2
# Word: られ, Count: 2

# %% [markdown]
# #### Figjam

# %%
import pandas as pd
import MeCab
import ipadic
from collections import Counter
import re

CHASEN_ARGS = r' -F "%m\t%f[7]\t%f[6]\t%F-[0,1,2,3]\t%f[4]\t%f[5]\n"'
CHASEN_ARGS += r' -U "%m\t%m\t%m\t%F-[0,1,2,3]\t\t\n"'

# CSVファイルのパス
filepath = 'material/fun_done_learn_10_24_10_30/figjam.csv'

# CSVファイルを読み込む
df = pd.read_csv(filepath)

# MeCabのインスタンスを作成
m = MeCab.Tagger(ipadic.MECAB_ARGS + CHASEN_ARGS)

# 単語をカウントする関数を定義
def count_words(text):
    if not isinstance(text, str):
        return []
    parsed_text = m.parse(text).splitlines()[:-1]
    words = []
    for word in parsed_text:
        word_parts = word.split('\t')
        if len(word_parts) >= 4 and not (word_parts[3].startswith('助詞') or word_parts[3].startswith('記号')):
            # Remove symbols from the word
            word_clean = re.sub(r'\W+', '', word_parts[0])
            if word_clean:
                words.append(word_clean)
    return words

# 'Content'列に関数を適用して新しい列を作成
df['Content_words'] = df['Content'].apply(count_words)

# 'Created by'でグループ化し、各グループの単語を集計
words_by_creator = df.groupby('Created by')['Content_words'].sum()

# 各作成者の最も頻繁に出現する単語の上位3つを計算
for creator, words in words_by_creator.items():
    word_counts = Counter(words)
    top_three = word_counts.most_common(10)
    print(f'Creator: {creator}')
    for word, count in top_three:
        print(f'    Word: {word}, Count: {count}')
# Out:
# Creator: Dai Miyahara
#     Word: た, Count: 3
#     Word: し, Count: 3
#     Word: でき, Count: 2
#     Word: モバイルヘッダー, Count: 1
#     Word: 用, Count: 1
#     Word: コンポーネント, Count: 1
#     Word: バグ, Count: 1
#     Word: らしき, Count: 1
#     Word: もの, Count: 1
#     Word: 発見, Count: 1
# Creator: FABIAN M. FERNANDEZ
#     Word: 開発, Count: 4
#     Word: フロント, Count: 2
#     Word: た, Count: 2
#     Word: Next, Count: 1
#     Word: js, Count: 1
#     Word: 所持, Count: 1
#     Word: 品, Count: 1
#     Word: リスト, Count: 1
#     Word: 各種, Count: 1
#     Word: 修正, Count: 1
# Creator: 中山建太
#     Word: た, Count: 11
#     Word: し, Count: 5
#     Word: ない, Count: 4
#     Word: こと, Count: 3
#     Word: 感, Count: 3
#     Word: られ, Count: 2
#     Word: 対応, Count: 2
#     Word: CSS, Count: 2
#     Word: の, Count: 2
#     Word: 会社, Count: 2
# Creator: 大野寛人
#     Word: た, Count: 5
#     Word: タスク, Count: 2
#     Word: 動け, Count: 2
#     Word: なかっ, Count: 2
#     Word: 今週, Count: 1
#     Word: 引き取っ, Count: 1
#     Word: 関わら, Count: 1
#     Word: ず, Count: 1
#     Word: 引っ越し, Count: 1
#     Word: 何, Count: 1
# Creator: 平田聖
#     Word: た, Count: 10
#     Word: し, Count: 6
#     Word: CORS, Count: 3
#     Word: 設定, Count: 2
#     Word: 修正, Count: 2
#     Word: BE, Count: 2
#     Word: 側, Count: 2
#     Word: 調べ, Count: 2
#     Word: 時間, Count: 2
#     Word: まし, Count: 2
# Creator: 水野響
#     Word: た, Count: 5
#     Word: でき, Count: 3
#     Word: 2, Count: 2
#     Word: NextAuth, Count: 1
#     Word: 検証, Count: 1
#     Word: DONE, Count: 1
#     Word: ちょっと, Count: 1
#     Word: Next, Count: 1
#     Word: 追従, Count: 1
#     Word: て, Count: 1
# Creator: 鈴木真希
#     Word: た, Count: 3
#     Word: ツール, Count: 2
#     Word: こと, Count: 2
#     Word: git, Count: 1
#     Word: 使い方, Count: 1
#     Word: 以前, Count: 1
#     Word: 比べる, Count: 1
#     Word: 少し, Count: 1
#     Word: わかる, Count: 1
#     Word: よう, Count: 1
