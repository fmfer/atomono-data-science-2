# %% [markdown]
# # 文字数

# %% [markdown]
# 'Elephants'
# JIRA: 5025
# Figma: 1338
# Notion: 6004
# Slack: 59963
#
# 'fun_done_learn'
# JIRA: 4320
# Figma: 1247
# Notion: 4624
# Slack: 50238
#
# 'speed_car'
# JIRA: 5326
# Figma: 1582
# Notion: 3892
# Slack: 38712
#
# 'star_fish'
# JIRA: 2618
# Figma: 1080
# Notion: 6004
# Slack: 48435
#
# 'KPT'
# JIRA:　1435
# Notion:　4535
# Slack:　26454

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

# 実施順の振り返り手法
# df = pd.Data['Elephants', 'Fun Done Learn', 'Speedcar', 'Starfish', 'KPT'])
RETRO_KINDS = ['KPT', 'Speedcar', 'Starfish', 'Fun Done Learn', 'Elephants'] 

# データをDataFrameに変換
CHAR_NUMS = {
    # 'JIRA': [5025, 4320, 5326, 2618, 1435],
    'JIRA': [1435, 5326, 2618, 4320, 5025],
    # 'Notion': [6004, 4624, 3892, 6004, 4535],
    'Notion': [4535, 3892, 6004, 4624, 6004,],
    # 'Slack': [59963, 50238, 38712, 48435, 26454]
    'Slack': [26454, 38712, 48435, 50238, 59963]
}

df = pd.DataFrame(CHAR_NUMS, index=RETRO_KINDS)

# データを正規化
# df_normalized = df.apply(lambda x: 2 * (x - x.min()) / (x.max() - x.min()) - 1)

# 折れ線グラフを描画
plt.plot(df['JIRA'], marker='o', label='JIRA')
plt.plot(df['Notion'], marker='v', label='Notion')
plt.plot(df['Slack'], marker='s', label='Slack')
plt.title('')
plt.xlabel('Name of Retrospective')
plt.ylabel('Number of characters (normalized)')
line1 = mlines.Line2D([], [], color='blue', marker='o', linestyle='-', markersize=10)
line2 = mlines.Line2D([], [], color='orange', marker='v', linestyle='-', markersize=10)
line3 = mlines.Line2D([], [], color='green', marker='s', linestyle='-', markersize=10)
plt.legend(handles=[line1, line2, line3], labels=['JIRA', 'Notion', 'Slack'], title='')
plt.grid(True)
plt.savefig("word.png")   
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

# 実施順の振り返り手法
# df = pd.Data['Elephants', 'Fun Done Learn', 'Speedcar', 'Starfish', 'KPT'])
RETRO_KINDS = ['KPT', 'Speedcar', 'Starfish', 'Fun Done Learn', 'Elephants'] 

# データをDataFrameに変換
CHAR_NUMS = {
    # 'JIRA': [5025, 4320, 5326, 2618, 1435],
    'JIRA': [1435, 5326, 2618, 4320, 5025],
    # 'Notion': [6004, 4624, 3892, 6004, 4535],
    'Notion': [4535, 3892, 6004, 4624, 6004,],
    # 'Slack': [59963, 50238, 38712, 48435, 26454]
    'Slack': [26454, 38712, 48435, 50238, 59963]
}

df = pd.DataFrame(CHAR_NUMS, index=RETRO_KINDS)

# データを正規化
df_normalized = df.apply(lambda x: 2 * (x - x.min()) / (x.max() - x.min()) - 1)

# 折れ線グラフを描画
plt.plot(df_normalized['JIRA'], marker='o', label='JIRA')
plt.plot(df_normalized['Notion'], marker='v', label='Notion')
plt.plot(df_normalized['Slack'], marker='s', label='Slack')
plt.title('')
plt.xlabel('Name of Retrospective')
plt.ylabel('Number of characters (normalized)')
line1 = mlines.Line2D([], [], color='blue', marker='o', linestyle='-', markersize=10)
line2 = mlines.Line2D([], [], color='orange', marker='v', linestyle='-', markersize=10)
line3 = mlines.Line2D([], [], color='green', marker='s', linestyle='-', markersize=10)
plt.legend(handles=[line1, line2, line3], labels=['JIRA', 'Notion', 'Slack'], title='')
plt.grid(True)
plt.savefig("word.png")   
plt.show()

# %%
# df = pd.Data  ['Elephants', 'Fun Done Learn', 'Speedcar', 'Starfish', 'KPT'])
# RETRO_KINDS = ['KPT', 'Speedcar', 'Starfish', 'Fun Done Learn', 'Elephants'] 

# データをDataFrameに変換
# data = {
#     'JIRA': [5025, 4320, 5326, 2618, 1435],
#     'Notion': [6004, 4624, 3892, 6004, 4535],
#     'Slack': [59963, 50238, 38712, 48435, 26454]
# }
df = pd.DataFrame(CHAR_NUMS, index=RETRO_KINDS)

# # データを正規化
# df_normalized = df.apply(lambda x: 2 * (x - x.min()) / (x.max() - x.min()) - 1)

# 積み上げ棒グラフを描画
df.plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Normalized Data')
plt.xlabel('Name of Retrospective')
plt.ylabel('Number of characters (normalized)')
plt.show()

# %%
# df = pd.Data  ['Elephants', 'Fun Done Learn', 'Speedcar', 'Starfish', 'KPT'])
# RETRO_KINDS = ['KPT', 'Speedcar', 'Starfish', 'Fun Done Learn', 'Elephants'] 

# データをDataFrameに変換
# data = {
#     'JIRA': [5025, 4320, 5326, 2618, 1435],
#     'Notion': [6004, 4624, 3892, 6004, 4535],
#     'Slack': [59963, 50238, 38712, 48435, 26454]
# }
df = pd.DataFrame(CHAR_NUMS, index=RETRO_KINDS)

# データを正規化
df_normalized = df.apply(lambda x: 2 * (x - x.min()) / (x.max() - x.min()) - 1)

# 積み上げ棒グラフを描画
df_normalized.plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Normalized Data')
plt.xlabel('Name of Retrospective')
plt.ylabel('Number of characters (normalized)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df = pd.Data['Elephants', 'Fun Done Learn', 'Speedcar', 'Starfish'])
# RETRO_KINDS ['Speedcar', 'Starfish', 'Fun Done Learn', 'Elephants'] 

# データをDataFrameに変換
CHAR_NUMS_FIGMA = {
    'Figma': [1080, 1247, 1582, 1338],
}
RETRO_KINDS_WITHOUT_KPT = RETRO_KINDS[1:]
df = pd.DataFrame(CHAR_NUMS_FIGMA, index=RETRO_KINDS_WITHOUT_KPT)

# # データを正規化
# df_normalized = df.apply(lambda x: 2 * (x - x.min()) / (x.max() - x.min()) - 1)

# 折れ線グラフを描画
df.plot(kind='line', marker='*', fontsize=16)
plt.title('')
plt.xlabel('Name of Retrospective', fontsize=16)
plt.ylabel('Number of characters (normalized)', fontsize=16)
plt.legend(title='')
plt.grid(True)
plt.savefig("word2.png")   
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df = pd.Data['Elephants', 'Fun Done Learn', 'Speedcar', 'Starfish'])
# RETRO_KINDS ['Speedcar', 'Starfish', 'Fun Done Learn', 'Elephants'] 

# データをDataFrameに変換
CHAR_NUMS_FIGMA = {
    'Figma': [1080, 1247, 1582, 1338],
}
RETRO_KINDS_WITHOUT_KPT = RETRO_KINDS[1:]
df = pd.DataFrame(CHAR_NUMS_FIGMA, index=RETRO_KINDS_WITHOUT_KPT)

# データを正規化
df_normalized = df.apply(lambda x: 2 * (x - x.min()) / (x.max() - x.min()) - 1)

# 折れ線グラフを描画
df_normalized.plot(kind='line', marker='*', fontsize=16)
plt.title('')
plt.xlabel('Name of Retrospective', fontsize=16)
plt.ylabel('Number of characters (normalized)', fontsize=16)
plt.legend(title='')
plt.grid(True)
plt.savefig("word2.png")   
plt.show()

# %% [markdown]
# # 文章量

# %% [markdown]
# 'Elephants'
# JIRA: 179
# Figma: 49
# Notion: 243
# Slack: 1609
#
# 'fun_done_learn'
# JIRA: 101
# Figma: 39
# Notion: 215
# Slack: 1378
#
# 'speed_car'
# JIRA: 131
# Figma: 58
# Notion: 157
# Slack: 998
#
# 'star_fish'
# JIRA: 69
# Figma: 44
# Notion: 211
# Slack: 1375
#
# 'KPT'
# JIRA: 28
# Notion: 194
# Slack: 705

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 旧['Elephants', 'Fun Done Learn', 'Speedcar', 'Starfish', 'KPT'])
#   ['KPT', 'Speedcar', 'Starfish', 'Fun Done Learn', 'Elephants'] 

# データをDataFrameに変換
SENCENCE_NUMS = {
    # 'JIRA': [179, 101, 131, 69, 28],
    'JIRA': [28, 131, 69, 101, 179],
    # 'Notion': [243, 215, 157, 211, 194],
    'Notion': [194, 157, 211, 215, 243],
    # 'Slack': [1609, 1378, 998, 1375, 705]
    'Slack': [705, 998, 1375, 1378, 1609]
}
df = pd.DataFrame(SENCENCE_NUMS, index=RETRO_KINDS)

# データを正規化
df_normalized = df.apply(lambda x: 2 * (x - x.min()) / (x.max() - x.min()) - 1)

# 折れ線グラフを描画
df_normalized['JIRA'].plot(marker='o', fontsize=12, label='JIRA')
df_normalized['Notion'].plot(marker='v', fontsize=12, label='Notion')
df_normalized['Slack'].plot(marker='s', fontsize=12, label='Slack')
plt.title('')
plt.xlabel('Name of Retrospective', fontsize=12)
plt.ylabel('Number of characters (normalized)', fontsize=12)
plt.legend(title='')
plt.grid(True)
plt.savefig("sentence.png")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 旧['Elephants', 'Fun Done Learn', 'Speedcar', 'Starfish'])
#   ['Speedcar', 'Starfish', 'Fun Done Learn', 'Elephants'] 

# データをDataFrameに変換
data = {
    # 'Figma': [49, 39, 58, 44],
    'Figma': [58, 44, 39, 49],
}
df = pd.DataFrame(data, index=RETRO_KINDS_WITHOUT_KPT)

# データを正規化
df_normalized = df.apply(lambda x: 2 * (x - x.min()) / (x.max() - x.min()) - 1)

# 折れ線グラフを描画
df_normalized.plot(kind='line', marker='*', fontsize=13)
plt.title('')
plt.xlabel('Name of Retrospective', fontsize=13)
plt.ylabel('Number of characters (normalized)', fontsize=13)
plt.legend(title='')
plt.grid(True)
plt.savefig("sentence2.png")   
plt.show()

# %% [markdown]
# # ネガポジ判定

# %% [markdown]
# <!-- ```
# [象、死んだ魚、嘔吐]
# Jira: -0.23718622222222227
# figma: -0.41282551020408154
# Notion: -0.45888
# Slack: -0.30290864864864847
#
# [fun,done,learn]
# Jira: -0.17936499999999997
# figma:  -0.46014461538461543
# Notion: -0.42706
# Slack: -0.3658764580369844
#
# [speed car]
# Jira:  -0.19673939393939394
# figma: -0.4717041379310345
# Notion: -0.46612
# Slack: -0.3019370212765958
#
#
# [star fish]
# Jira: -0.18830166666666664
# speed car: -0.5012749999999999
# Notion: -0.50544
# Slack: -0.3483183410852716
#
# [KPT]
# Jira: -0.34448266666666666
# Notion: -0.48176
# Slack: -0.3149776266666667
# ``` -->
#
# <!-- jiraは(1)ではない方を参照している. jiraはcreated_atでjira(1)はupdated_atで収集したデータらしい -->
# ```
# [KPT]
# Jira: 0.30363733333333337
# figma: ---
# Notion: 0.50962
# Slack: 0.447905
#
# [Speed car]
# Jira: 0.29944590909090907
# figma: 0.41265780128205126
# Notion: 0.50054
# Slack: 0.4164571428571428
#
# [starfish]
# Jira: 0.238856
# figma: 0.44850221088435377
# Notion: 0.51854
# Slack: 0.42198875
#
# [Fun Done Learn]
# Jira: 0.2276622727272727
# figma: 0.4414610416666666
# Notion: 0.49459
# Slack: 0.48874000000000006
#
# [象、死んだ魚、嘔吐]
# Jira: 0.19865688888888894
# figma: 0.4458968518518518
# Notion: 0.5173
# Slack: 0.48318999999999995
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 実施順
X_LABALS = ['KPT', 'Starfish', 'Fun Done Learn', 'Speedcar', 'Elephants']

# データをpandas DataFrameに格納
RETRO_SENTIMENT_SCORES = {
    'Keyword': RETRO_KINDS,
    # 'JIRA': [-0.23718622222222227, -0.17936499999999997, -0.19673939393939394, -0.18830166666666664, -0.34448266666666666],
    'JIRA': [0.30363733333333337, 0.29944590909090907, 0.238856, 0.2276622727272727, 0.19865688888888894],
    # 'Notion': [-0.45888, -0.42706, -0.46612, -0.50544, -0.48176],
    'Notion': [0.50962, 0.50054, 0.51854, 0.49459, 0.5173],
    # 'Slack': [-0.30290864864864847, -0.3658764580369844, -0.3019370212765958, -0.3483183410852716, -0.3149776266666667]
    'Slack': [0.447905, 0.4164571428571428, 0.42198875, 0.48874000000000006, 0.48318999999999995]
}

df = pd.DataFrame(RETRO_SENTIMENT_SCORES, index=X_LABALS)

# 折れ線グラフを描画
df['JIRA'].plot(kind='line', marker='o', label='JIRA', fontsize=12)
df['Notion'].plot(kind='line', marker='v', label='Notion', fontsize=12)
df['Slack'].plot(kind='line', marker='s', label='Slack', fontsize=12)
plt.title('')
plt.xlabel('Name of Retrospective', fontsize=12)
plt.ylabel('Values', fontsize=12)
plt.grid(True)
plt.legend(title='')

plt.savefig("negaposi.png")   

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# データをDataFrameに変換
# figma without kpt
# 'Starfish', 'Fun Done Learn', 'Speedcar', 'Elephants'
RETRO_SENTIMENT_FIGMA_SCORE = {
    # 'Figma': [-0.41282551020408154, -0.46014461538461543, -0.4717041379310345, -0.5012749999999999]
    'Figma': [0.44850221088435377, 0.4414610416666666, 0.41265780128205126, 0.4458968518518518]
}
df = pd.DataFrame(RETRO_SENTIMENT_FIGMA_SCORE, index=RETRO_KINDS_WITHOUT_KPT)


# 折れ線グラフを描画
df.plot(kind='line', marker='*', fontsize=16)
plt.title('')
plt.xlabel('Name of Retrospective', fontsize=16)
plt.ylabel('Values', fontsize=16)
plt.grid(True)
plt.savefig("negaposi2.png")   
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

# フォントサイズを設定
plt.rcParams.update({'font.size': 21})

# フィギュアとサブプロットを作成
fig, axs = plt.subplots(1, 3, figsize=(24, 7))

# データをDataFrameに変換
# Elephants, fundonelarn, speedcar, starfish, KPT
# ['KPT', 'Speedcar', 'Starfish', 'Fun Done Learn', 'Elephants']
data1 = {
    # 'JIRA': [5025, 4320, 5326, 2618, 1435],
    'JIRA': [1435, 5326, 2618, 4320, 5025],
    # 'Notion': [6004, 4624, 3892, 6004, 4535],
    'Notion': [4535, 3892, 6004, 4624, 6004],
    # 'Slack': [59963, 50238, 38712, 48435, 26454]
    'Slack': [26454, 38712, 48435, 50238, 59963]
}
df1 = pd.DataFrame(data1, index=RETRO_KINDS)

# データを正規化
df1_normalized = df1.apply(lambda x: 2 * (x - x.min()) / (x.max() - x.min()) - 1)

# 折れ線グラフを描画
axs[0].plot(df1_normalized['JIRA'], marker='o', markersize=10, label='JIRA')
axs[0].plot(df1_normalized['Notion'], marker='v', markersize=10, label='Notion')
axs[0].plot(df1_normalized['Slack'], marker='s', markersize=10, label='Slack')
axs[0].set_xlabel('Name of Retrospective', fontsize=16)
axs[0].set_ylabel('Number of characters (normalized)', fontsize=16)
axs[0].legend(title='')
axs[0].grid(True)
axs[0].set_ylim([-1.2, 1.2])  # y軸の上限と下限を設定

# データをDataFrameに変換
data2 = {
    # 'JIRA': [179, 101, 131, 69, 28],
    'JIRA': [28, 131, 69, 101, 179],
    # 'Notion': [243, 215, 157, 211, 194],
    'Notion': [194, 157, 211, 215, 243],
    # 'Slack': [1609, 1378, 998, 1375, 705]
    'Slack': [705, 998, 1375, 1378, 1609]
}
df2 = pd.DataFrame(data2, index=RETRO_KINDS)

# データを正規化
df2_normalized = df2.apply(lambda x: 2 * (x - x.min()) / (x.max() - x.min()) - 1)

# 折れ線グラフを描画
axs[1].plot(df2_normalized['JIRA'], marker='o', markersize=10, label='JIRA')
axs[1].plot(df2_normalized['Notion'], marker='v', markersize=10, label='Notion')
axs[1].plot(df2_normalized['Slack'], marker='s', markersize=10, label='Slack')
axs[1].set_xlabel('Name of Retrospective', fontsize=16)
axs[1].set_ylabel('Number of sentences (normalized)', fontsize=16)
axs[1].legend(title='')
axs[1].grid(True)
axs[1].yaxis.set_ticks(np.arange(-1, 1.5, 0.5))
axs[1].set_ylim([-1.2, 1.2])  # y軸の上限と下限を設定

# # データをpandas DataFrameに格納
# data3 = {
#     'Keyword': ['Elephants', 'Fun', 'Speedcar', 'Starfish', 'KPT'],
#     'JIRA': [-0.23718622222222227, -0.17936499999999997, -0.19673939393939394, -0.18830166666666664, -0.34448266666666666],
#     'Notion': [-0.45888, -0.42706, -0.46612, -0.50544, -0.48176],
#     'Slack': [-0.30290864864864847, -0.3658764580369844, -0.3019370212765958, -0.3483183410852716, -0.3149776266666667]
# }
# df3 = pd.DataFrame(data3, index=RETRO_KINDS)
df3 = pd.DataFrame(RETRO_SENTIMENT_SCORES, index=RETRO_KINDS)

# 折れ線グラフを描画
axs[2].plot(df3['JIRA'], marker='o', markersize=10, label='JIRA')
axs[2].plot(df3['Notion'], marker='v', markersize=10, label='Notion')
axs[2].plot(df3['Slack'], marker='s', markersize=10, label='Slack')
axs[2].set_xlabel('Name of Retrospective', fontsize=16)
axs[2].set_ylabel('Negative Positive Values (normalized)', fontsize=16)
axs[2].grid(True)
axs[2].legend(title='')
# axs[2].yaxis.set_ticks(np.arange(-0.6, 0, 0.1))
# axs[2].set_ylim([0, 0.9])  # y軸の上限と下限を設定

# フィギュアを保存
plt.tight_layout()
plt.savefig("combined.png")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams.update({'font.size': 21})

# データをDataFrameに変換
# 象, fundonelearn, speedcar, starfish
# data1 = {'Figma': [1338, 1247, 1582, 1080]} # 文字数
data1 = {'Figma': [1582, 1080, 1247, 1338]} # 文字数
# data2 = {'Figma': [49, 39, 58, 44]} #文章量
data2 = {'Figma': [58, 44, 39, 49]} #文章量
# data3 = {'Figma': [-0.41282551020408154, -0.46014461538461543, -0.4717041379310345, -0.5012749999999999]} #感情分析
data3 = RETRO_SENTIMENT_FIGMA_SCORE
index = RETRO_KINDS_WITHOUT_KPT # [speedcar, starfish, fun done learn, Elephants]
df1 = pd.DataFrame(data1, index=index)
df2 = pd.DataFrame(data2, index=index)
df3 = pd.DataFrame(data3, index=index)

# データを正規化
df1_normalized = df1.apply(lambda x: 2 * (x - x.min()) / (x.max() - x.min()) - 1)
df2_normalized = df2.apply(lambda x: 2 * (x - x.min()) / (x.max() - x.min()) - 1)

# フィギュアとサブプロットを作成
fig, axs = plt.subplots(1, 3, figsize=(24, 7))  # A4サイズに合わせる

# 折れ線グラフを描画
df1_normalized.plot(kind='line', marker='p', markersize=10, ax=axs[0])
df2_normalized.plot(kind='line', marker='p', markersize=10, ax=axs[1])
df3.plot(kind='line', marker='p', markersize=10, ax=axs[2])

# 各サブプロットの設定
axs[0].set_xlabel('Name of Retrospective')  # X軸のラベルを設定
axs[0].set_ylabel('Number of characters (normalized)')  # Y軸のラベルを設定
axs[0].legend(title='')
axs[0].grid(True)
axs[0].set_yticks(np.arange(-1, 1.2, 0.5))  # Y軸の単位を0.5に設定

axs[1].set_xlabel('Name of Retrospective')  # X軸のラベルを設定
axs[1].set_ylabel('Number of sentences (normalized)')  # Y軸のラベルを設定
axs[1].legend(title='')
axs[1].grid(True)
axs[1].set_yticks(np.arange(-1, 1.2, 0.5))  # Y軸の単位を0.5に設定

axs[2].set_xlabel('Name of Retrospective')  # X軸のラベルを設定
axs[2].set_ylabel('Negative Positive Values (normalized)')  # Y軸のラベルを設定
axs[2].legend(title='')
axs[2].grid(True)
# axs[2].yaxis.set_ticks(np.arange(-0.55, -0.35, 0.05))
# axs[2].set_ylim([-0.53, -0.37])  # y軸の上限と下限を設定

plt.tight_layout()
plt.savefig("combined2.png")   
plt.show()
